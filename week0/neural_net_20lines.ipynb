# %% [markdown]
# # Training a 2-Layer Neural Network in 20 lines
#
# From Stanford CSE231n http://cs231n.stanford.edu/slides/2019/cs231n_2019_lecture04.pdf

# %%
import numpy as np
from numpy.random import randn

N, D_in, H, D_out = 64, 1000, 100, 10
x, y = randn(N, D_in), randn(N, D_out)
w1, w2 = randn(D_in, H), randn(H, D_out)

for t in range(2000):
    h = 1 / (1 + np.exp(-x.dot(w1)))
    y_pred = h.dot(w2)
    loss = np.square(y_pred - y).sum()
    if t % 20 == 0:
        print(t, loss)
    
    grad_y_pred = 2.0 * (y_pred - y)
    grad_w2 = h.T.dot(grad_y_pred)
    grad_h = grad_y_pred.dot(w2.T)
    grad_w1 = x.T.dot(grad_h * h * (1 - h))
    
    w1 -= 1e-4 * grad_w1
    w2 -= 1e-4 * grad_w2
# Out:
# 0 31447.342659729893
# 20 6657.972943085506
# 40 4621.387550372484
# 60 3505.4573066966095
# 80 2763.896626850939
# 100 2195.3226652677613
# 120 1813.7970182792822
# 140 1513.9246813435648
# 160 1286.0563756044562
# 180 1095.0260976818472
# 200 937.7511292866311
# 220 816.9146594062349
# 240 713.770520803134
# 260 623.9604664837806
# 280 554.3258115606287
# 300 496.65717609232445
# 320 446.7587177883407
# 340 403.74854590432756
# 360 366.08105376052396
# 380 332.55213045626544
# 400 302.21606873956625
# 420 274.6289461490097
# 440 250.65566943272904
# 460 229.6799622739661
# 480 210.92255521322707
# 500 193.85457176610328
# 520 177.9091767056207
# 540 163.5104044626306
# 560 150.39244986034026
# 580 138.3754077196976
# 600 128.06786958005
# 620 118.98640778505927
# 640 110.84108445115844
# 660 103.5034703603548
# 680 96.83444454848919
# 700 90.70933034516864
# 720 85.013200800001
# 740 79.6208383163651
# 760 74.41581477978555
# 780 69.64749091996713
# 800 65.4668960606088
# 820 61.64934565297973
# 840 58.12142659500749
# 860 54.846045455071
# 880 51.79489351466739
# 900 48.94411301822455
# 920 46.273465133966496
# 940 43.767899431571486
# 960 41.417863402023336
# 980 39.216201647990545
# 1000 37.15485545666671
# 1020 35.224504914192096
# 1040 33.41538871989961
# 1060 31.717519002177994
# 1080 30.12085057187547
# 1100 28.615980667738036
# 1120 27.194937359997517
# 1140 25.85139390298275
# 1160 24.58026132773404
# 1180 23.37697143635193
# 1200 22.236958219419527
# 1220 21.156029595223046
# 1240 20.131629330330806
# 1260 19.163306067647174
# 1280 18.250847388236544
# 1300 17.392090675273906
# 1320 16.58309562557738
# 1340 15.819605453302607
# 1360 15.09790647022347
# 1380 14.414923963020168
# 1400 13.768049563906711
# 1420 13.154974870624272
# 1440 12.57358854856467
# 1460 12.021923154404707
# 1480 11.498131193482592
# 1500 11.00047650267495
# 1520 10.527332401718443
# 1540 10.07718130485764
# 1560 9.648613051338426
# 1580 9.240321274038667
# 1600 8.851098250167738
# 1620 8.479828930341998
# 1640 8.125484702017962
# 1660 7.78711728439467
# 1680 7.46385306610129
# 1700 7.154888115036655
# 1720 6.85948392376703
# 1740 6.5769636706495955
# 1760 6.306708434724076
# 1780 6.048152562713527
# 1800 5.8007774619669
# 1820 5.564103611222161
# 1840 5.337681422106039
# 1860 5.121082345620939
# 1880 4.913891823512053
# 1900 4.71570514602563
# 1920 4.52612628571552
# 1940 4.344768894606308
# 1960 4.171258287643369
# 1980 4.005233403532432
